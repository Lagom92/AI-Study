# %% [markdown]
# # Matplotlib

# %% [markdown]
# # 1. Matplotlib 소개

# %% [markdown]
# ### matplotlib 임포트와 쥬피터노트북에 플롯 삽입 준비

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# - plt
#     - 인터페이스 부분을 가장 많이 담당하는 pyplot 모듈
#
# - `%`로 시작하는 매직 명령어
#
# - %matplotlib
#     - notebook
#         - 노트북 사용 시 interactive한 시각화 도구를 사용
#     - inline
#         - inline 사용 시 정적으로 plot를 집어넣는 방식

# %% [markdown]
# ### 플롯 스타일과 설정

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %% [markdown]
# - pyplot 모듈의 style 정보 내 available 속성의 정보 다수

# %%
plt.style.use("seaborn-whitegrid")

# %% [markdown]
# - use를 이용해서 session 전체에 스타일을 결정

# %% [markdown]
# # 2. 라인 플롯

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)

plt.plot(x, np.sin(x), "-", linewidth=1, label="sin(x)")
plt.plot(x, np.cos(x), '--', linewidth=1, label="cos(x)")
plt.xlim(0, 10)
plt.ylim(-1, 1)
plt.title("Sine & Cosine Curve")
plt.xlabel("x")
plt.legend()

# %% [markdown]
# - linespace() 함수를 이용해서 데이터 만들기
#
# - 라인 플롯을 그리는 plot() 함수(x의 함수값 sin그래프)
#
# - plt.plot(x좌표, y좌표, 포맷)
#
#     - 포맷: color, line의 스타일, 포인트의 모양 등 결정
#         - 라인의 스타일 지정
#             - "-" : solid(실선)
#             - "--" : dotted(점선)
#
#     - linewidth: 라인의 폭 지정
#     - label: 범례 표시 문자열 지정
#
# - xlim(최소값, 최대값): x의 limit 지정
#
# - ylim(최소값, 최대값): y의 limit 지정
#
# - title: 타이틀 지정
#
# - plt.legend()
#     - 범례 지정
#     - 위에서 지정한 라벨을 이용함

# %% [markdown]
# ### 스타일 컨텍스트 매니저를 이용한 플롯 스타일의 일시적 설정 변경
#
# - plt.style.context()로 plot 스타일을 일시적으로 변경함

# %%
with plt.style.context("ggplot"):
    plt.plot(x, np.sin(x), "-.", linewidth=1, label="sin(x)")
    plt.plot(x, np.cos(x), ':', linewidth=1, label="cos(x)")
    plt.xlim(0, 10)
    plt.ylim(-1, 1)
    plt.title("Sine & Cosine Curve")
    plt.xlabel("x")
    plt.legend()

# %% [markdown]
# ### 객체지향 인터페이스 Figure와 Axes 객체의 사용
#
# - 객체 지향 인터페이스 Figure는 `면`, 그림을 그리기 위한 캔버스
#
# - 축 정보가 포함된 Axes
#     - xticks, yticks

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 100)

ax.plot(x, np.sin(x), "-", linewidth=1, label="sin(x)")
ax.plot(x, np.cos(x), '--', linewidth=1, label="cos(x)")
ax.set_xlim([0, 10])
ax.set_ylim([-1, 1])
ax.set_title("Sine & Cosine Curve")
ax.set_xlabel("x")
ax.legend()

# %% [markdown]
# - plt를 대신한 Axes 객체 작업에는 set 메소드가 포함됨

# %% [markdown]
# ### subplots 함수를 이용해 2개의 플롯 그리기

# %%
fig, ax = plt.subplots(2, 1)

ax[0].plot(x, np.sin(x), 'b-', linewidth=0.5, label="sin(x)")
ax[0].set_title("Sine & Cosine Curve")
ax[0].set(xlim=[0, 10], ylim=[-1, 1])
ax[0].legend()

ax[1].plot(x, np.cos(x), 'g-', linewidth=0.5, label="cos(x)")
ax[1].set(xlim=[0, 10], ylim=[-1, 1], xlabel="x")
ax[1].legend()

# %% [markdown]
# - ax\[0\] => 위쪽 그래프
# - ax\[1\] => 아래쪽 그래프
#
# - 컬러 패턴
#     - "b-": 블루, 실선
#     - "g-": 그린, 실선
#
# - set 메소드에 속성값 파라미터로 지정하기

# %% [markdown]
# ### 매트랩 스타일 pylab 인터페이스의 사용
#
# - plt 객체를 이용해 pylab 인터페이스 사용하기

# %%
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x), 'b-', linewidth=0.5, label="sin(x)")
plt.title("Sine & Cosine Curve")
plt.axis([0, 10, -1, 1])
plt.legend()

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x), 'g-', linewidth=0.5, label="cos(x)")
plt.xlabel("x")
plt.axis([0, 10, -1, 1])
plt.legend()

# %% [markdown]
# - plt.subplot(행, 열, 위치)
#     - 전체적인 도면의 행과 열 설정
#     - 그리고자 하는 그림의 위치 설정(plot의 위치)
#
# - plt.axis()
#     - xlim, ylim

# %%
plt.plot(x, np.sin(x), "-", linewidth=1)
plt.title("Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.margins(0, 0)
plt.axis("equal")
# Out:
# (0.0, 10.0, -0.9993845576124357, 0.9996923408861117)

# %% [markdown]
# - plt.axis("equal")
#
#     - equal값을 주면 축과 축이 동일한 크기로 유지됨
#     - 종횡비 걱정 없이 쓸 수 있는 편의 기능

# %% [markdown]
# <br/>
#
# ### 이어서...
#
# 3. matplotlib-2
